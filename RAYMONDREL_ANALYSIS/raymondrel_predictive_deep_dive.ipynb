# %% [markdown]
# # Raymond Realty Limited (RAYMONDREL) Multidimensional Forecast Deep Dive
# ### Stock: RAYMONDREL.NS | ISIN: INE1SY401010
# **Foundation Framework**: Google TimesFM 3.0 + Multi-Agent Triad (Technical Momentum + Fundamental GDV + Real Estate Macro)
# **Session Context**: September 3, 2026 Close: **₹531.35 (+5.00% Daily Breakout)**

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt

with open('raymondrel_prediction_results.json') as f:
    data = json.load(f)

m = data['market_summary']
print(f'Symbol:          {data["ticker"]}')
print(f'Sep 3 Close:     Rs. {m["today_close_sep3"]:.2f} (+{m["today_change_pct"]}%)')
print(f'Market Cap:      Rs. {m["market_cap_cr"]:,.2f} Cr')
print(f'GDV Pipeline:    Rs. {m["gdv_pipeline_cr"]:,.2f} Cr')
print(f'Thane Landbank:  {m["thane_landbank_acres"]} Acres')
print(f'1-Month Target:  Rs. {data["weighted_1month_target"]:.2f}')

# %% [markdown]
# ## 1. 22-Day Forward Multidimensional Forecast Fan Chart

# %%
from IPython.display import Image
Image('raymondrel_multidim_forecast_22d.png')

# %% [markdown]
# ## 2. Technical Breakout Levels & Real Estate Peer Valuation Comparison

# %%
Image('raymondrel_technical_breakout_matrix.png')

# %% [markdown]
# ## 3. Date-Wise Daily Forecast Schedule (Sep 4 to Oct 2, 2026)

# %%
df_sched = pd.DataFrame(data['daily_schedule'])
df_sched.head(10)
