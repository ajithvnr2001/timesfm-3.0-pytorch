# %% [markdown]
# # Monday, September 7, 2026 Market Prediction Deep Dive
# ### Framework: Google TimesFM 3.0 + Multi-Agent Triad
# **Conditioned on Market Close**: Friday, September 4, 2026
# **Primary Target Assets**: NIFTY 50, Options Playbook (Sep 10), Hindustan Zinc, Raymond Realty, Modison, Gold Futures

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt

with open('monday_sep7_predictions.json') as f:
    data = json.load(f)

print('Monday Pivots for NIFTY 50:', data['pivots'])

# %% [markdown]
# ## 1. NIFTY 50 Hourly Forecast Chart (Monday, Sep 7)

# %%
from IPython.display import Image
Image('timesfm3_nifty_monday_sep7_forecast.png')

# %% [markdown]
# ## 2. Monday Cross-Asset Forecast Matrix (Nifty, Hindzinc, Raymond Realty, Gold)

# %%
Image('monday_cross_asset_forecast_sep7_2026.png')

# %% [markdown]
# ## 3. Monday Hourly Schedule Table

# %%
df_hourly = pd.DataFrame(data['hourly_forecast'])
df_hourly[['hour', 'time', 'phase', 'pred', 'p25', 'p75', 'bias']]
